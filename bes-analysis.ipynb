# %%
import beams
import profiles
import optics_calculations
import plotfida

import matplotlib
matplotlib.rcParams['figure.dpi'] = 100

save_figures = False
# Out:
# /Users/drsmith/Documents/W7X-feasibility-study/python/pybaseutils/plt_utils.py:15: MatplotlibDeprecationWarning:
# The mpl_toolkits.axes_grid module was deprecated in Matplotlib 2.1 and will be removed two minor releases later. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist, which provide the same functionality instead.
#   from mpl_toolkits.axes_grid.inset_locator import inset_axes
# /Users/drsmith/anaconda3/envs/py3/lib/python3.7/site-packages/grequests.py:22: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.contrib.pyopenssl (/Users/drsmith/anaconda3/envs/py3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py)'].
#   curious_george.patch_all(thread=False, select=False)

# %% [markdown]
# # Field alignment and Doppler shift along beam axis

# %%
pinis = [beams.HeatingBeam(pini=pini, bvoltage=60e3, species='protium') for pini in [1,2,3,4]]
pinis[1].plot_onaxis(save=save_figures)

# %% [markdown]
# # Field alignment and Doppler shift in beam vertical plane

# %%
pinis[1].plot_vertical_plane(port='A21-lolo', save=save_figures)

# %% [markdown]
# # Beam-weighted sightline calculations

# %%
r_obs, z_obs = 5.8, -0.4
pinis[1].plot_sightline(port='A21-lolo', r_obs=r_obs, z_obs=z_obs, save=save_figures)

# %% [markdown]
# # Profiles

# %%
profiles.fit_profiles(save_figures=save_figures)
# Out:
# Getting ne data for shot 180904027
#   Using data in profiles.pickle
# Getting te data for shot 180904027
#   Using data in profiles.pickle
# Getting ti data for shot 180904027
#   Using data in profiles.pickle

# %% [markdown]
# # Spot size, collection lens, and optical fibers

# %%
optics_calculations.plot(save=save_figures)

# %% [markdown]
# # FIDASIM emission spectrum

# %%
plotfida.plotfida(ilos=1, save=save_figures)
# Out:
# FIDASIM results: /Users/drsmith/Documents/W7X-feasibility-study/analysis/fida_0046
# No. lines of sight: 5
# No. waveleghts: 2000
# Min/Max wavelength: 647.0 nm / 667.0 nm
# Wavelength resolution: 0.010 nm
#    0: A21_P2_R568_Zm40
#    1: A21_P2_R576_Zm40
#    2: A21_P2_R584_Zm40
#    3: A21_P2_R576_Zm32
#    4: A21_P2_R576_Zm48
